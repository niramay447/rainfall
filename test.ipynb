# %%
from src.dataset import prepare_dataset

def main():
  prepare_dataset(
    radar_filepath="sg_radar_data",
    cml_filepath=None,
    raingauge_filepath=None
  )

main()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from src.dataset import prepare_dataset
#       3 def main():
#       4   prepare_dataset(
#       5     radar_filepath="sg_radar_data",
#       6     cml_filepath=None,
#       7     raingauge_filepath=None
#       8   )
#
# File ~/Documents/FYP/rainfall_data_fusion/src/dataset.py:3
#       1 import pandas as pd
# ----> 3 from radar.utils import load_radar_dataset
#       5 def prepare_dataset(
#       6     radar_filepath: str,
#       7     raingauge_filepath: str,
#       8     cml_filepath: str
#       9 ) -> pd.DataFrame:
#      10   '''
#      11   Prepares the dataset for CML, Radar and Rain Gauge
#      12   Returns: Dataframe with all data sources aligned in 15 minute timestep
#      13   '''
#
# ModuleNotFoundError: No module named 'radar'
